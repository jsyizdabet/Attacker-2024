# %%
import vnstock as vnst

# %%
# filter using vnstock
# Sàn giao dịch: HOSE, HXN, UPCOM
# Vốn hóa thị trường: trên 100 tỷ
# ROE trên 20%
params = {
            "exchangeName": "HOSE,HNX,UPCOM",
            "marketCap": (100,999999),
            "roe": (0.2, 1)
        }
filter1 = vnst.stock_screening_insights (params, size=1700, drop_lang='vi')

# %%
len(filter1.columns)
# filter1.columns
# Out:
# 80

# %%
# Tăng trưởng doanh thu/ lợi nhuận so với quý trước
filter2 = filter1[filter1['lastQuarterRevenueGrowth'] > 0]

# %%
# Tăng trưởng EPS so với quý trước: EPSchange > 0
indicesToRemove = []
for index, co in filter2.iterrows():
    ptTaiChinh = vnst.financial_ratio(co[0], 'quarterly', True)
    if ptTaiChinh['Q3-2023']['epsChange'] <= 0:
        indicesToRemove.append(index)
#         filter2.loc[index, :] = None
        print(ptTaiChinh['Q3-2023']['epsChange'])
filter2.loc[indicesToRemove, :] = None
# Out:
# -0.44
# -0.534
# -0.227
# -1.683
# -0.049
# -0.342
# -1.359
# -0.555
# -0.245
# -0.5
# -0.036
# -0.303
# -0.874
# -0.569
# -0.233
# -0.728
# -2.157

# %%
filter2.dropna(subset=['ticker'], inplace = True);
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14352\4178191988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2.dropna(subset=['ticker'], inplace = True);

# %%
filter2
# Out:
#    ticker companyName  marketCap  roe  stockRating  businessOperation  \
# 5     CBI                  301.0  0.3          2.0                1.2
# 12    FCN                 2228.0  0.4          2.3                1.4
# 17    HTP                 1230.0  0.4          2.0                2.8
# 20    KOS                 8638.0  0.9          1.9                1.8
# 22    LIG                  396.0  0.7          2.3                1.3
# 34    PSB                  320.0  0.8          2.5                1.7
# 37    PVB                  447.0  0.9          2.5                1.2
# 43    SDU                  366.0  0.5          2.2                3.1
# 47    SRF                  287.0  0.4          1.9                1.1
# 50    TLH                  891.0  0.2          2.0                1.2
# 57    VNG                  875.0  0.3          1.9                1.8
#
#     businessModel  financialHealth  alpha  beta  ...  rsi14Status.en  \
# 5             3.0              1.8    0.1   0.3  ...         Neutral
# 12            3.0              2.6    0.0   1.8  ...         Neutral
# 17            2.7              3.0   -0.5   0.2  ...         Neutral
# 20            2.5              2.8    0.0   0.0  ...         Neutral
# 22            3.2              3.0   -0.1   1.8  ...         Neutral
# 34            NaN              4.2    0.1   0.3  ...             NaN
# 37            3.0              4.8    0.2   1.3  ...         Neutral
# 43            3.5              2.4   -0.1   0.2  ...         Neutral
# 47            3.5              2.4    0.0   0.0  ...         Neutral
# 50            3.0              2.4    0.0   1.5  ...         Neutral
# 57            3.2              2.4    0.0   0.3  ...         Neutral
#
#     hasFinancialReport.en      priceVsSMA100.en  foreignTransaction.en  \
# 5                     Yes  Price above SMA(100)                    NaN
# 12                    Yes  Price below SMA(100)             Buy < Sell
# 17                    Yes  Price below SMA(100)                    NaN
# 20                    Yes  Price above SMA(100)             Buy > Sell
# 22                    Yes  Price below SMA(100)                    NaN
# 34                    Yes                   NaN                    NaN
# 37                    Yes  Price below SMA(100)             Buy < Sell
# 43                    Yes  Price below SMA(100)                    NaN
# 47                    Yes  Price above SMA(100)                    NaN
# 50                    Yes  Price below SMA(100)             Buy > Sell
# 57                    Yes  Price above SMA(100)                    NaN
#
#     breakout.en            priceVsSma10.en  tcbsRecommend.en  uptrend.en  \
# 5           NaN                        NaN               NaN         NaN
# 12          NaN  Price cross below SMA(10)       Wait to buy         NaN
# 17   Buy Signal  Price cross above SMA(10)               NaN  Buy Signal
# 20          NaN                        NaN               NaN         NaN
# 22          NaN                        NaN               NaN         NaN
# 34          NaN                        NaN               NaN         NaN
# 37          NaN  Price cross below SMA(10)               NaN         NaN
# 43  Sell Signal  Price cross below SMA(10)               NaN         NaN
# 47          NaN  Price cross below SMA(10)               NaN         NaN
# 50          NaN                        NaN      Wait to sell         NaN
# 57          NaN                        NaN               NaN         NaN
#
#     bollingBandSignal.en  sarVsMacdHist.en
# 5                    NaN               NaN
# 12           Sell signal               NaN
# 17            Buy signal               NaN
# 20                   NaN               NaN
# 22                   NaN               NaN
# 34                   NaN               NaN
# 37           Sell signal               NaN
# 43           Sell signal               NaN
# 47           Sell signal               NaN
# 50                   NaN               NaN
# 57                   NaN               NaN
#
# [11 rows x 80 columns]
